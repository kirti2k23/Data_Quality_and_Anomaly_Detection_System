# %%
from src.Data_quality_and_anomaly_detection.componenets.data_preprocessing import DataPreprocessing
import pandas as pd

# %%
datapreprocessing = DataPreprocessing(output_path = "raw_csv")
csv_path = datapreprocessing.convert_excel_to_csv()

# %%
df = pd.read_csv(csv_path)

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
missing_df = df[df.isnull().any(axis=1)]

# %%
missing_df.shape
# Out:
# (135080, 8)

# %%
missing_df.loc[:,'CustomerID'] = None
missing_df.loc[:,"Description"] = None
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_3320\4010251399.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'None' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   missing_df.loc[:,'CustomerID'] = None

# %%
df["null_count"]  = df.isnull().sum(axis=1
                                    )

# %%
df["null_count"].sum()
# Out:
# np.int64(136534)

# %%
missing_df.shape[0]
# Out:
# 135080

# %%
min_null_column = 1
batch_size = 5000
# count null per rows 
df["null_count"]  = df.isnull().sum(axis=1)

# selec rows with atleast missing nulls
missing_df = df[df['null_count']>=min_null_column]

if missing_df.empty:
    pass

# Focus on known problematic column
missing_df.loc[:,'CustomerID'] = None
missing_df.loc[:,'Description'] = None

#Sample fixed batch size
missing_batch  =  missing_df.sample( n = min(batch_size,missing_df.shape[0]),
                                    random_state= 42)
missing_batch.drop(columns=["null_count"], inplace= True)
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_4304\108285536.py:13: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'None' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   missing_df.loc[:,'CustomerID'] = None

# %%
missing_batch.head()
# Out:
#        InvoiceNo StockCode Description  Quantity          InvoiceDate  \
# 107790    545464     22624        None         1  2011-03-03 09:10:00
# 181708    552508     22998        None         2  2011-05-09 16:27:00
# 61217     541424     22335        None         1  2011-01-17 17:57:00
# 169305    551173    84970S        None         5  2011-04-26 16:54:00
# 238450    557938     23205        None         1  2011-06-23 15:35:00
#
#         UnitPrice CustomerID         Country
# 107790       8.50       None  United Kingdom
# 181708       0.83       None  United Kingdom
# 61217        1.25       None  United Kingdom
# 169305       2.08       None  United Kingdom
# 238450       1.63       None  United Kingdom

# %%
# get invalid values
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country  null_count
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom           0
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom           0
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom           0
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom           0
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom           0

# %%
len(df[df['UnitPrice']<0])
# Out:
# 2

# %%
max(df['Quantity'])
# Out:
# 80995

# %%
from src.Data_quality_and_anomaly_detection.componenets.data_batch_generator import DataBatchGenerator
import pandas as pd
bacthgenerator = DataBatchGenerator()
missing_schema_path = bacthgenerator.create_missing_schema_batch()
missing_df = pd.read_csv(missing_schema_path)

# %%
missing_file = bacthgenerator.create_missing_value_batch()
missing_df = pd.read_csv(missing_file)
# Out:
# c:\users\shiva\desktop\placement_preparation\git_repository\data_quality_and_anomaly_detection_system\src\Data_quality_and_anomaly_detection\componenets\data_batch_generator.py:57: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'None' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.

# %%
missing_df.isnull().sum()
# Out:
# InvoiceNo         0
# StockCode         0
# Description    5000
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# CustomerID     5000
# Country           0
# dtype: int64

# %%
total_rows = len(missing_df)

# %%
total_rows
# Out:
# 135080

# %%
5000/135080
# Out:
# 0.03701510216168197
